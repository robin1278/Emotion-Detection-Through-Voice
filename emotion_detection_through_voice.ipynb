# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display

paths = []
labels = []
for dirname,_, filenames in os.walk('C:\\Users\\Om Sai\\Desktop\\Machine Learning Internship\\Project 5\\TESS Toronto emotional speech set data'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())
        # print(labels)
    if len(paths) == 2800:
        break
print('Dataset is Loaded')

# print(len(paths))

print(paths[0:5])
print(labels[0:5])

# Create a dataframe
df = pd.DataFrame()
df['speech'] = paths
df['label'] = labels
print(df.head())

print(df['label'].value_counts())


print(sns.countplot(data=df, x='label'))

def waveplot(data, sr, emotion):
    plt.figure(figsize=(10,4))
    plt.title(emotion, size=20)
    librosa.display.waveshow(data, sr=sr)
    plt.show()
    
def spectogram(data, sr, emotion):
    x = librosa.stft(data)
    xdb = librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(11,4))
    plt.title(emotion, size=20)
    librosa.display.specshow(xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.colorbar()

emotion = 'fear'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)

emotion = 'angry'
path = np.array(df['speech'][df['label']==emotion])[1]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
# Audio(path)

emotion = 'disgust'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
# Audio(path)

emotion = 'neutral'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
# Audio(path)

emotion = 'sad'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
# Audio(path)

emotion = 'ps'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
# Audio(path)

emotion = 'happy'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
# Audio(path)
# print(Audio(path))    

def extract_mfcc(filename):
    y, sr = librosa.load(filename, duration=3, offset=0.5)
    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
    return mfcc

extract_mfcc(df['speech'][0])
X_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))
X_mfcc

X = [x for x in X_mfcc]
X = np.array(X)
X = np.expand_dims(X, -1)
X.shape

from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y = enc.fit_transform(df[['label']])
y = y.toarray()
print(y.shape)

from keras.models import Sequential # type: ignore
from keras.layers import Dense, LSTM, Dropout # type: ignore

model = Sequential([
    LSTM(256, return_sequences=False, input_shape=(40,1)),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(7, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
history = model.fit(X, y, validation_split=0.2, epochs=50, batch_size=64)

epochs = list(range(50))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

model.save("emotion_detection_model.h5")
# Out:
# Dataset is Loaded
# ['C:\\Users\\Om Sai\\Desktop\\Machine Learning Internship\\Project 5\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_back_angry.wav', 'C:\\Users\\Om Sai\\Desktop\\Machine Learning Internship\\Project 5\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_bar_angry.wav', 'C:\\Users\\Om Sai\\Desktop\\Machine Learning Internship\\Project 5\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_base_angry.wav', 'C:\\Users\\Om Sai\\Desktop\\Machine Learning Internship\\Project 5\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_bath_angry.wav', 'C:\\Users\\Om Sai\\Desktop\\Machine Learning Internship\\Project 5\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_bean_angry.wav']
# ['angry', 'angry', 'angry', 'angry', 'angry']
#                                               speech  label
# 0  C:\Users\Om Sai\Desktop\Machine Learning Inter...  angry
# 1  C:\Users\Om Sai\Desktop\Machine Learning Inter...  angry
# 2  C:\Users\Om Sai\Desktop\Machine Learning Inter...  angry
# 3  C:\Users\Om Sai\Desktop\Machine Learning Inter...  angry
# 4  C:\Users\Om Sai\Desktop\Machine Learning Inter...  angry
# label
# angry      200
# disgust    200
# fear       200
# happy      200
# neutral    200
# ps         200
# sad        200
# Name: count, dtype: int64
# Axes(0.125,0.11;0.775x0.77)
# (1400, 7)
# c:\Users\Om Sai\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 256)            │       264,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │           455 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 305,799 (1.17 MB)
#  Trainable params: 305,799 (1.17 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 179ms/step - accuracy: 0.4496 - loss: 1.5525 - val_accuracy: 0.0857 - val_loss: 3.7861
# Epoch 2/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.8013 - loss: 0.5334 - val_accuracy: 0.1786 - val_loss: 4.9665
# Epoch 3/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.8443 - loss: 0.4135 - val_accuracy: 0.1679 - val_loss: 5.1924
# Epoch 4/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.8851 - loss: 0.3198 - val_accuracy: 0.2714 - val_loss: 5.8961
# Epoch 5/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - accuracy: 0.9264 - loss: 0.2102 - val_accuracy: 0.2571 - val_loss: 5.6348
# Epoch 6/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 185ms/step - accuracy: 0.9606 - loss: 0.1246 - val_accuracy: 0.2679 - val_loss: 6.0803
# Epoch 7/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - accuracy: 0.9592 - loss: 0.1632 - val_accuracy: 0.2714 - val_loss: 5.4681
# Epoch 8/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - accuracy: 0.9625 - loss: 0.1077 - val_accuracy: 0.2679 - val_loss: 6.6559
# Epoch 9/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - accuracy: 0.9685 - loss: 0.1017 - val_accuracy: 0.2429 - val_loss: 6.3364
# Epoch 10/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 197ms/step - accuracy: 0.9702 - loss: 0.1141 - val_accuracy: 0.2107 - val_loss: 7.3820
# Epoch 11/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 186ms/step - accuracy: 0.9595 - loss: 0.1540 - val_accuracy: 0.2643 - val_loss: 7.0075
# Epoch 12/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - accuracy: 0.9802 - loss: 0.0759 - val_accuracy: 0.2607 - val_loss: 7.5243
# Epoch 13/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 198ms/step - accuracy: 0.9857 - loss: 0.0589 - val_accuracy: 0.2857 - val_loss: 9.3159
# Epoch 14/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - accuracy: 0.9867 - loss: 0.0437 - val_accuracy: 0.2500 - val_loss: 8.7047
# Epoch 15/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 209ms/step - accuracy: 0.9887 - loss: 0.0336 - val_accuracy: 0.2571 - val_loss: 8.5361
# Epoch 16/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - accuracy: 0.9816 - loss: 0.0683 - val_accuracy: 0.2536 - val_loss: 6.4158
# Epoch 17/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 211ms/step - accuracy: 0.9636 - loss: 0.1024 - val_accuracy: 0.2679 - val_loss: 6.9940
# Epoch 18/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - accuracy: 0.9778 - loss: 0.0758 - val_accuracy: 0.2643 - val_loss: 8.3611
# Epoch 19/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 260ms/step - accuracy: 0.9849 - loss: 0.0603 - val_accuracy: 0.2679 - val_loss: 8.8089
# Epoch 20/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 250ms/step - accuracy: 0.9887 - loss: 0.0324 - val_accuracy: 0.2786 - val_loss: 8.8273
# Epoch 21/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 252ms/step - accuracy: 0.9908 - loss: 0.0338 - val_accuracy: 0.2500 - val_loss: 10.3095
# Epoch 22/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 216ms/step - accuracy: 0.9827 - loss: 0.0546 - val_accuracy: 0.2607 - val_loss: 6.8284
# Epoch 23/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 237ms/step - accuracy: 0.9893 - loss: 0.0281 - val_accuracy: 0.2643 - val_loss: 8.9396
# Epoch 24/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 216ms/step - accuracy: 0.9906 - loss: 0.0322 - val_accuracy: 0.2714 - val_loss: 8.7902
# Epoch 25/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 224ms/step - accuracy: 0.9969 - loss: 0.0152 - val_accuracy: 0.2643 - val_loss: 9.7748
# Epoch 26/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 227ms/step - accuracy: 0.9902 - loss: 0.0298 - val_accuracy: 0.2429 - val_loss: 8.7399
# Epoch 27/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 217ms/step - accuracy: 0.9859 - loss: 0.0286 - val_accuracy: 0.2750 - val_loss: 9.1277
# Epoch 28/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - accuracy: 0.9982 - loss: 0.0079 - val_accuracy: 0.2571 - val_loss: 10.2196
# Epoch 29/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 195ms/step - accuracy: 0.9776 - loss: 0.1114 - val_accuracy: 0.2750 - val_loss: 9.6844
# Epoch 30/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 206ms/step - accuracy: 0.9755 - loss: 0.0852 - val_accuracy: 0.2607 - val_loss: 6.9341
# Epoch 31/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 222ms/step - accuracy: 0.9952 - loss: 0.0194 - val_accuracy: 0.2679 - val_loss: 7.0356
# Epoch 32/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 226ms/step - accuracy: 0.9947 - loss: 0.0265 - val_accuracy: 0.2643 - val_loss: 8.1912
# Epoch 33/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 235ms/step - accuracy: 0.9851 - loss: 0.0600 - val_accuracy: 0.2571 - val_loss: 6.3964
# Epoch 34/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 201ms/step - accuracy: 0.9925 - loss: 0.0236 - val_accuracy: 0.2607 - val_loss: 8.7489
# Epoch 35/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 202ms/step - accuracy: 0.9933 - loss: 0.0229 - val_accuracy: 0.2500 - val_loss: 8.5103
# Epoch 36/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - accuracy: 0.9932 - loss: 0.0174 - val_accuracy: 0.2643 - val_loss: 8.6642
# Epoch 37/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 233ms/step - accuracy: 0.9952 - loss: 0.0131 - val_accuracy: 0.2643 - val_loss: 9.1238
# Epoch 38/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 239ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.2643 - val_loss: 9.6613
# Epoch 39/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 237ms/step - accuracy: 0.9981 - loss: 0.0044 - val_accuracy: 0.2536 - val_loss: 9.8805
# Epoch 40/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 235ms/step - accuracy: 0.9963 - loss: 0.0052 - val_accuracy: 0.2857 - val_loss: 9.6524
# Epoch 41/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 221ms/step - accuracy: 0.9914 - loss: 0.0281 - val_accuracy: 0.2750 - val_loss: 9.2327
# Epoch 42/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 250ms/step - accuracy: 0.9953 - loss: 0.0093 - val_accuracy: 0.2571 - val_loss: 9.2031
# Epoch 43/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 220ms/step - accuracy: 0.9998 - loss: 0.0025 - val_accuracy: 0.2714 - val_loss: 9.4551
# Epoch 44/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 224ms/step - accuracy: 0.9988 - loss: 0.0052 - val_accuracy: 0.2643 - val_loss: 10.5068
# Epoch 45/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 240ms/step - accuracy: 0.9955 - loss: 0.0203 - val_accuracy: 0.2643 - val_loss: 7.0641
# Epoch 46/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 221ms/step - accuracy: 0.9736 - loss: 0.0957 - val_accuracy: 0.2750 - val_loss: 6.2921
# Epoch 47/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 244ms/step - accuracy: 0.9844 - loss: 0.0424 - val_accuracy: 0.2536 - val_loss: 7.2992
# Epoch 48/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 231ms/step - accuracy: 0.9942 - loss: 0.0220 - val_accuracy: 0.2643 - val_loss: 8.0657
# Epoch 49/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 242ms/step - accuracy: 0.9943 - loss: 0.0239 - val_accuracy: 0.2571 - val_loss: 9.2789
# Epoch 50/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 259ms/step - accuracy: 0.9971 - loss: 0.0111 - val_accuracy: 0.2571 - val_loss: 8.6482
# C:\Users\Om Sai\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
